# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from prep_plays import explore_plays_data, prep_plays_data
from wrangle_plays_data import train_validate_test, min_max_scale
# Out:
# Acquire.py Loaded Successfully
# Prep.py Loaded Successfully
# Wrangle.py Loaded Successfully

# %%
train, validate, test = explore_plays_data()

# %% [markdown]
# # Does the offense formation matter? i.e. (is a certain offensive formation harder to defend?)

# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
alpha = .05

# %% [markdown]
# - $H_0$: There is no dependence between offensive formation and pass stopped
# - $H_a$: There is a dependence between offensive formation and pass stopped

# %%
observed = pd.crosstab(train.offenseFormation, train.pass_stopped)

# %%
chi2, p, degf, expected = stats.chi2_contingency(observed)

# %%
if p < alpha:
    print("We reject the null hypothesis")
else:
    print("We fail to reject the null hypothesis")
p
# Out:
# We reject the null hypothesis
# 0.019278800162284792

# %%
train.offenseFormation.value_counts()
# Out:
# SHOTGUN       4704
# SINGLEBACK    1022
# EMPTY          944
# I_FORM         346
# PISTOL          88
# JUMBO            4
# Name: offenseFormation, dtype: int64

# %%
form = train[train.offenseFormation != 'JUMBO']
form = form[form.offenseFormation != 'PISTOL']

# %%
custom_palette = ["black", "red"]

# %%
ax = sns.catplot(x="offenseFormation", hue="pass_stopped", kind="count", data=form, height=8, aspect=1.5, palette = custom_palette)
ax._legend.remove()
plt.title('', size = 40, c = 'white')
plt.xlabel('', size = 30, c = 'white')
plt.ylabel('Number of Passes Stopped', size = 30, c = 'white')
plt.legend(labels = ('Pass Completed', 'Pass Stopped'), loc='center right', frameon=False, fontsize='x-large')
plt.xticks([0, 1, 2, 3], ['Shotgun', 'Empty', 'Singleback', 'I Formation'], size = 30, c = 'white')
plt.yticks(size = 30, c = 'white')
plt.show()

# %%
barplot = plt.bar(y_pos, odds_number, color = 'darkgreen', alpha = 0.85)
barplot[0].set_color('darkred')

# %% [markdown]
# **Takeaways:**
# - There does not seem to be a certain formation that will have there pass stopped more than others
# - After a statistical test, we can safely say that there is not dependence on stopping the play and the formation the offense is lined up in.

# %%
train.groupby('offenseFormation').pass_stopped.count()
# Out:
# offenseFormation
# EMPTY          944
# I_FORM         346
# JUMBO            4
# PISTOL          88
# SHOTGUN       4704
# SINGLEBACK    1022
# Name: pass_stopped, dtype: int64

# %%
train[train.pass_stopped ==1].groupby('offenseFormation').pass_stopped.count()
# Out:
# offenseFormation
# EMPTY          308
# I_FORM         101
# JUMBO            3
# PISTOL          28
# SHOTGUN       1687
# SINGLEBACK     339
# Name: pass_stopped, dtype: int64

# %% [markdown]
# # What defense schemes work to prevent a successful pass?

# %%
train.T

# %%
  #setting conditions for conference
    conditions = [
        #west teams
        (nba.Team.isin(['LAL', 'LAC', 'DEN', 'HOU', 'OKC', 'UTA', 'DAL', 'POR', 'MEM', 'PHO', 'SAS', 'SAC', 'NOP', 'MIN', 'GSW'])),
        #east teams
        (nba.Team.isin(['MIL', 'TOR', 'BOS', 'IND', 'MIA', 'PHI', 'BRK', 'ORL', 'WAS', 'CHO', 'CHI', 'NYK', 'DET', 'ATL', 'CLE']))]
    choices = ['home_is_west', 'home_is_east']
    #creating conference column for home team
    nba['Conference'] = np.select(conditions, choices, default='west')

# %%
train.personnelD.value_counts()

# %%
conditions = [
    (np.where((df['DL'] == 4) & (df['LB'] == 3),1,0)), 
    (np.where((df['DL'] == 3) & (df['LB'] == 4),1,0)),
    (np.where(df['DB'] == 5, 1, 0)),
    (np.where(df['DB'] == 6, 1, 0))]
choices =  ['four_three', 'three_four', 'nickel', 'dime']
df['defenseFormation'] = np.select(conditions, choices)

# %% [markdown]
# # Grid Search CV

# %% [markdown]
# ## Gradient Boost

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import RidgeClassifierCV
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
df = prep_plays_data()

# %%
df.T
# Out:
#                                                                     0      \
# playDescription         (15:00) M.Ryan pass short right to J.Jones pus...
# quarter                                                                 1
# down                                                                    1
# yardsToGo                                                              15
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       7
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        15:00:00
# absoluteYardlineNumber                                                 90
# epa                                                              0.261827
# pass_stopped                                                            0
# playResult                                                             10
# RB                                                                      2
# TE                                                                      1
# WR                                                                      2
# DL                                                                      4
# LB                                                                      2
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  1
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 0
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     1      \
# playDescription         (13:10) M.Ryan pass incomplete short right to ...
# quarter                                                                 1
# down                                                                    1
# yardsToGo                                                              10
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       7
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        13:10:00
# absoluteYardlineNumber                                                 49
# epa                                                              -0.37236
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      4
# LB                                                                      2
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 0
# SINGLEBACK                                                              1
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     2      \
# playDescription         (13:05) (Shotgun) M.Ryan pass incomplete short...
# quarter                                                                 1
# down                                                                    2
# yardsToGo                                                              10
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        13:05:00
# absoluteYardlineNumber                                                 49
# epa                                                             -0.702779
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      2
# TE                                                                      1
# WR                                                                      2
# DL                                                                      4
# LB                                                                      2
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     3      \
# playDescription         (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# quarter                                                                 1
# down                                                                    3
# yardsToGo                                                              10
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     5
# QB_under_pressure                                                     1.0
# gameClock                                                        13:01:00
# absoluteYardlineNumber                                                 49
# epa                                                               3.04753
# pass_stopped                                                            0
# playResult                                                             33
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      4
# LB                                                                      1
# DB                                                                      6
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  0
# dime                                                                    1
#
#                                                                     4      \
# playDescription         (10:59) (Shotgun) M.Ryan pass incomplete short...
# quarter                                                                 1
# down                                                                    3
# yardsToGo                                                               1
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       8
# numberOfPassRushers                                                     6
# QB_under_pressure                                                     0.0
# gameClock                                                        10:59:00
# absoluteYardlineNumber                                                 11
# epa                                                             -0.842272
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      2
# TE                                                                      3
# WR                                                                      0
# DL                                                                      6
# LB                                                                      3
# DB                                                                      2
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  0
# dime                                                                    0
#
#                                                                     5      \
# playDescription         (10:10) (Shotgun) N.Foles pass short left to N...
# quarter                                                                 1
# down                                                                    2
# yardsToGo                                                               8
# team_by_comp_yds                                                        8
# defendersInTheBox                                                       7
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        10:10:00
# absoluteYardlineNumber                                                 14
# epa                                                             -0.344096
# pass_stopped                                                            0
# playResult                                                              4
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      3
# LB                                                                      3
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     6      \
# playDescription         (9:24) (Shotgun) N.Foles pass incomplete short...
# quarter                                                                 1
# down                                                                    3
# yardsToGo                                                               4
# team_by_comp_yds                                                        8
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        09:24:00
# absoluteYardlineNumber                                                 18
# epa                                                              -1.19221
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      1
# TE                                                                      2
# WR                                                                      2
# DL                                                                      3
# LB                                                                      3
# DB                                                                      5
# EMPTY                                                                   1
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 0
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     7      \
# playDescription         (9:08) M.Ryan pass incomplete deep left to M.S...
# quarter                                                                 1
# down                                                                    1
# yardsToGo                                                              10
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       7
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     1.0
# gameClock                                                        09:08:00
# absoluteYardlineNumber                                                 54
# epa                                                             -0.429863
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      4
# LB                                                                      2
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 0
# SINGLEBACK                                                              1
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     8      \
# playDescription         (7:01) M.Ryan pass short left to T.Coleman pus...
# quarter                                                                 1
# down                                                                    2
# yardsToGo                                                              13
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       8
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        07:01:00
# absoluteYardlineNumber                                                 46
# epa                                                                1.8798
# pass_stopped                                                            0
# playResult                                                             26
# RB                                                                      1
# TE                                                                      2
# WR                                                                      2
# DL                                                                      4
# LB                                                                      2
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 0
# SINGLEBACK                                                              1
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     9      \
# playDescription         (6:19) M.Ryan pass short left to A.Hooper to P...
# quarter                                                                 1
# down                                                                    1
# yardsToGo                                                              10
# team_by_comp_yds                                                        3
# defendersInTheBox                                                       8
# numberOfPassRushers                                                     3
# QB_under_pressure                                                     0.0
# gameClock                                                        06:19:00
# absoluteYardlineNumber                                                 20
# epa                                                             0.0456651
# pass_stopped                                                            0
# playResult                                                              3
# RB                                                                      1
# TE                                                                      2
# WR                                                                      2
# DL                                                                      4
# LB                                                                      2
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 0
# SINGLEBACK                                                              1
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                         ...  \
# playDescription         ...
# quarter                 ...
# down                    ...
# yardsToGo               ...
# team_by_comp_yds        ...
# defendersInTheBox       ...
# numberOfPassRushers     ...
# QB_under_pressure       ...
# gameClock               ...
# absoluteYardlineNumber  ...
# epa                     ...
# pass_stopped            ...
# playResult              ...
# RB                      ...
# TE                      ...
# WR                      ...
# DL                      ...
# LB                      ...
# DB                      ...
# EMPTY                   ...
# I_FORM                  ...
# JUMBO                   ...
# PISTOL                  ...
# SHOTGUN                 ...
# SINGLEBACK              ...
# WILDCAT                 ...
# four_three              ...
# three_four              ...
# nickel                  ...
# dime                    ...
#
#                                                                     16997  \
# playDescription         (7:39) (Shotgun) P.Rivers pass incomplete shor...
# quarter                                                                 4
# down                                                                    2
# yardsToGo                                                               6
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     6
# QB_under_pressure                                                     0.0
# gameClock                                                        07:39:00
# absoluteYardlineNumber                                                 51
# epa                                                             -0.697479
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      2
# LB                                                                      4
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     16998  \
# playDescription         (7:35) (Shotgun) P.Rivers pass short right to ...
# quarter                                                                 4
# down                                                                    3
# yardsToGo                                                               6
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     5
# QB_under_pressure                                                     0.0
# gameClock                                                        07:35:00
# absoluteYardlineNumber                                                 51
# epa                                                               1.45309
# pass_stopped                                                            0
# playResult                                                              7
# RB                                                                      1
# TE                                                                      0
# WR                                                                      4
# DL                                                                      1
# LB                                                                      4
# DB                                                                      6
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  0
# dime                                                                    1
#
#                                                                     16999  \
# playDescription         (6:51) P.Rivers pass short right to J.Jackson ...
# quarter                                                                 4
# down                                                                    1
# yardsToGo                                                              10
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        06:51:00
# absoluteYardlineNumber                                                 44
# epa                                                             0.0831711
# pass_stopped                                                            0
# playResult                                                              6
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      2
# LB                                                                      4
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 0
# SINGLEBACK                                                              1
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     17000  \
# playDescription         (2:54) (Shotgun) P.Rivers pass short left to A...
# quarter                                                                 4
# down                                                                    1
# yardsToGo                                                              20
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     5
# QB_under_pressure                                                     0.0
# gameClock                                                        02:54:00
# absoluteYardlineNumber                                                 59
# epa                                                              -9.48768
# pass_stopped                                                            0
# playResult                                                            -51
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      2
# LB                                                                      4
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     17001  \
# playDescription         (2:40) (Shotgun) P.Rivers pass short left to K...
# quarter                                                                 4
# down                                                                    1
# yardsToGo                                                              10
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     5
# QB_under_pressure                                                     0.0
# gameClock                                                        02:40:00
# absoluteYardlineNumber                                                 85
# epa                                                            0.00452572
# pass_stopped                                                            0
# playResult                                                              8
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      1
# LB                                                                      5
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     17002  \
# playDescription         (2:19) (Shotgun) P.Rivers pass short right to ...
# quarter                                                                 4
# down                                                                    2
# yardsToGo                                                               2
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        02:19:00
# absoluteYardlineNumber                                                 77
# epa                                                              0.460543
# pass_stopped                                                            0
# playResult                                                              7
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      1
# LB                                                                      5
# DB                                                                      5
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  1
# dime                                                                    0
#
#                                                                     17003  \
# playDescription         (2:00) (Shotgun) P.Rivers pass short left to K...
# quarter                                                                 4
# down                                                                    1
# yardsToGo                                                              10
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       4
# numberOfPassRushers                                                     5
# QB_under_pressure                                                     0.0
# gameClock                                                        02:00:00
# absoluteYardlineNumber                                                 70
# epa                                                              0.712741
# pass_stopped                                                            0
# playResult                                                             17
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      1
# LB                                                                      4
# DB                                                                      6
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  0
# dime                                                                    1
#
#                                                                     17004  \
# playDescription         (1:41) (Shotgun) P.Rivers pass incomplete shor...
# quarter                                                                 4
# down                                                                    1
# yardsToGo                                                              10
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       5
# numberOfPassRushers                                                     5
# QB_under_pressure                                                     0.0
# gameClock                                                        01:41:00
# absoluteYardlineNumber                                                 53
# epa                                                             -0.229687
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      1
# LB                                                                      4
# DB                                                                      6
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  0
# dime                                                                    1
#
#                                                                     17005  \
# playDescription         (1:37) (Shotgun) P.Rivers pass incomplete deep...
# quarter                                                                 4
# down                                                                    2
# yardsToGo                                                              10
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       4
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        01:37:00
# absoluteYardlineNumber                                                 53
# epa                                                             -0.460746
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      1
# LB                                                                      4
# DB                                                                      6
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  0
# dime                                                                    1
#
#                                                                     17006
# playDescription         (1:31) (Shotgun) P.Rivers pass deep middle int...
# quarter                                                                 4
# down                                                                    3
# yardsToGo                                                              10
# team_by_comp_yds                                                       19
# defendersInTheBox                                                       6
# numberOfPassRushers                                                     4
# QB_under_pressure                                                     0.0
# gameClock                                                        01:31:00
# absoluteYardlineNumber                                                 53
# epa                                                              -2.74369
# pass_stopped                                                            1
# playResult                                                              0
# RB                                                                      1
# TE                                                                      1
# WR                                                                      3
# DL                                                                      1
# LB                                                                      4
# DB                                                                      6
# EMPTY                                                                   0
# I_FORM                                                                  0
# JUMBO                                                                   0
# PISTOL                                                                  0
# SHOTGUN                                                                 1
# SINGLEBACK                                                              0
# WILDCAT                                                                 0
# four_three                                                              0
# three_four                                                              0
# nickel                                                                  0
# dime                                                                    1
#
# [30 rows x 17001 columns]

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = train_validate_test(df)

# %%
X_train_scaled, X_validate_scaled, X_test_scaled = min_max_scale(X_train, X_validate, X_test)

# %%
X_train_scaled.T
# Out:
#                            12331     9633      13947     15562     5458   \
# quarter                 0.750000  0.750000  0.750000  0.500000  0.750000
# down                    0.000000  0.666667  0.000000  0.333333  0.000000
# yardsToGo               0.350000  0.200000  0.225000  0.225000  0.225000
# team_by_comp_yds        0.129032  0.967742  0.419355  0.741935  0.290323
# defendersInTheBox       0.444444  0.555556  0.444444  0.444444  0.555556
# numberOfPassRushers     0.500000  0.500000  0.500000  0.500000  0.500000
# QB_under_pressure       0.000000  0.000000  0.000000  0.000000  0.000000
# absoluteYardlineNumber  0.551020  0.530612  0.653061  0.204082  0.397959
# epa                     0.504938  0.438884  0.516462  0.487386  0.500943
# DL                      0.333333  0.666667  0.666667  0.500000  0.666667
# LB                      0.666667  0.333333  0.166667  0.500000  0.333333
# DB                      0.500000  0.500000  0.666667  0.500000  0.500000
# four_three              0.000000  0.000000  0.000000  0.000000  0.000000
# three_four              0.000000  0.000000  0.000000  0.000000  0.000000
# nickel                  1.000000  1.000000  0.000000  1.000000  1.000000
# dime                    0.000000  0.000000  1.000000  0.000000  0.000000
#
#                            9060      7240      11494     3899      4911   ...  \
# quarter                 0.500000  0.250000  0.500000  0.750000  0.750000  ...
# down                    0.666667  0.666667  0.000000  0.000000  0.000000  ...
# yardsToGo               0.150000  0.225000  0.225000  0.225000  0.225000  ...
# team_by_comp_yds        0.193548  0.516129  0.516129  0.935484  0.645161  ...
# defendersInTheBox       0.555556  0.444444  0.666667  0.555556  0.555556  ...
# numberOfPassRushers     0.500000  0.500000  0.625000  0.750000  0.500000  ...
# QB_under_pressure       0.000000  0.000000  0.000000  0.000000  0.000000  ...
# absoluteYardlineNumber  0.969388  0.091837  0.846939  0.602041  0.663265  ...
# epa                     0.472021  0.714156  0.498758  0.534833  0.523429  ...
# DL                      0.500000  0.666667  0.666667  0.666667  0.500000  ...
# LB                      0.333333  0.166667  0.500000  0.166667  0.666667  ...
# DB                      0.666667  0.666667  0.333333  0.666667  0.333333  ...
# four_three              0.000000  0.000000  1.000000  0.000000  0.000000  ...
# three_four              0.000000  0.000000  0.000000  0.000000  1.000000  ...
# nickel                  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# dime                    1.000000  1.000000  0.000000  1.000000  0.000000  ...
#
#                            13238     4813      15921     5634      7271   \
# quarter                 0.000000  0.500000  0.000000  0.250000  0.000000
# down                    0.333333  0.333333  0.666667  0.000000  0.333333
# yardsToGo               0.200000  0.175000  0.075000  0.225000  0.400000
# team_by_comp_yds        0.258065  0.612903  0.870968  0.741935  0.290323
# defendersInTheBox       0.666667  0.555556  0.555556  0.555556  0.333333
# numberOfPassRushers     0.500000  0.625000  0.500000  0.625000  0.500000
# QB_under_pressure       0.000000  0.000000  0.000000  0.000000  0.000000
# absoluteYardlineNumber  0.163265  0.612245  0.551020  0.561224  0.489796
# epa                     0.578176  0.490003  0.633970  0.534033  0.507766
# DL                      0.666667  0.333333  0.500000  0.333333  0.666667
# LB                      0.333333  0.666667  0.500000  0.666667  0.500000
# DB                      0.500000  0.500000  0.500000  0.500000  0.333333
# four_three              0.000000  0.000000  0.000000  0.000000  1.000000
# three_four              0.000000  0.000000  0.000000  0.000000  0.000000
# nickel                  1.000000  1.000000  1.000000  1.000000  0.000000
# dime                    0.000000  0.000000  0.000000  0.000000  0.000000
#
#                            14217     15210     7739      14947     641
# quarter                 0.750000  0.000000  0.000000  0.750000  0.750000
# down                    0.000000  0.333333  0.666667  0.333333  0.333333
# yardsToGo               0.225000  0.225000  0.175000  0.000000  0.225000
# team_by_comp_yds        0.612903  0.967742  0.000000  0.451613  1.000000
# defendersInTheBox       0.666667  0.555556  0.444444  0.555556  0.555556
# numberOfPassRushers     0.625000  0.500000  0.625000  0.625000  0.500000
# QB_under_pressure       0.000000  0.000000  0.000000  0.000000  0.000000
# absoluteYardlineNumber  0.295918  0.602041  0.642857  0.285714  0.397959
# epa                     0.514925  0.581803  0.434986  0.507255  0.510363
# DL                      0.666667  0.666667  0.666667  0.666667  0.333333
# LB                      0.333333  0.500000  0.166667  0.333333  0.666667
# DB                      0.500000  0.333333  0.666667  0.500000  0.500000
# four_three              0.000000  1.000000  0.000000  0.000000  0.000000
# three_four              0.000000  0.000000  0.000000  0.000000  0.000000
# nickel                  1.000000  0.000000  0.000000  1.000000  1.000000
# dime                    0.000000  0.000000  1.000000  0.000000  0.000000
#
# [16 rows x 7140 columns]

# %%
boost_params = {'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]}

# %%
ml = GridSearchCV(GradientBoostingClassifier(), boost_params, cv=5)
ml.fit(X_train_scaled, y_train)
print(ml.score(X_train_scaled, y_train))
# Out:
# 0.9009803921568628

# %%
y_pred = ml.predict(X_train_scaled)

# %%
cm = pd.DataFrame(confusion_matrix(y_train, y_pred))
cm
# Out:
#       0     1
# 0  4119   523
# 1   184  2314

# %%
class_report = pd.DataFrame(classification_report(y_train, y_pred, output_dict=True))
class_report
# Out:
#                      0            1  accuracy    macro avg  weighted avg
# precision     0.957239     0.815650   0.90098     0.886445      0.907703
# recall        0.887333     0.926341   0.90098     0.906837      0.900980
# f1-score      0.920961     0.867479   0.90098     0.894220      0.902250
# support    4642.000000  2498.000000   0.90098  7140.000000   7140.000000

# %%
### Gradient Boost

print(ml.score(X_validate_scaled, y_validate))
# Out:
# 0.8836134453781512

# %%
y_pred_val = ml.predict(X_validate_scaled)

# %%
cm = pd.DataFrame(confusion_matrix(y_pred_val, y_validate))
cm
# Out:
#       0     1
# 0  2680   139
# 1   415  1526

# %%
class_report = pd.DataFrame(classification_report(y_validate, y_pred_val, output_dict=True))
class_report
# Out:
#                      0            1  accuracy    macro avg  weighted avg
# precision     0.950692     0.786193  0.883613     0.868442      0.893152
# recall        0.865913     0.916517  0.883613     0.891215      0.883613
# f1-score      0.906324     0.846367  0.883613     0.876346      0.885352
# support    3095.000000  1665.000000  0.883613  4760.000000   4760.000000

# %%
print(ml.score(X_test_scaled, y_test))
# Out:
# 0.8806116447755342

# %% [markdown]
# ## Select Percentile

# %%
from sklearn.feature_selection import SelectPercentile

# %%
select = SelectPercentile(percentile=30) 
select.fit(X_train_scaled, y_train)

# %%
X_train_selected = select.transform(X_train_scaled)

# %%
print("X_train.shape: {}".format(X_train_scaled.shape)) 
print("X_train_selected.shape: {}".format(X_train_selected.shape))

# %%
mask = select.get_support()
print(mask)
# visualize the mask -- black is True, white is False 
plt.matshow(mask.reshape(1, -1), cmap='gray_r') 
plt.xlabel("Sample index")

# %%
X_train_select5 = X_train_scaled[['down', 'numberOfPassRushers', 'QB_under_pressure', 'epa', 'DB']]

# %%
ml = GridSearchCV(GradientBoostingClassifier(), boost_params, cv=5)
ml.fit(X_train_select5, y_train)
print(ml.score(X_train_select5, y_train))

# %%
y_pred_select = ml.predict(X_train_select5)

# %%
cm = pd.DataFrame(confusion_matrix(y_train, y_pred_select))
cm

# %% [markdown]
# ## Select From Model

# %%
from sklearn.feature_selection import SelectFromModel

# %%
select = SelectFromModel(
        GradientBoostingClassifier(),
        threshold="median")

select.fit(X_train_scaled, y_train)
X_train_l1 = select.transform(X_train_scaled) 
print("X_train.shape: {}".format(X_train_scaled.shape)) 
print("X_train_l1.shape: {}".format(X_train_l1.shape))

mask = select.get_support()
# visualize the mask -- black is True, white is False 
plt.matshow(mask.reshape(1, -1), cmap='gray_r') 
plt.xlabel("Sample index")

# %%
X_train_scaled

# %%
X_train_scaled_select8 = X_train_scaled[['quarter', 'down', 'yardsToGo', 'team_by_comp_yds', 'numberOfPassRushers', 'QB_under_pressure', 'absoluteYardlineNumber', 'epa']]

# %%
ml = GridSearchCV(GradientBoostingClassifier(), boost_params, cv=5)
ml.fit(X_train_scaled_select8, y_train)
print(ml.score(X_train_scaled_select8, y_train))

# %%
y_pred = ml.predict(X_train_scaled_select8)

# %%
cm = pd.DataFrame(confusion_matrix(y_train, y_pred))
cm

# %%
class_report = pd.DataFrame(classification_report(y_train, y_pred, output_dict=True))
class_report

# %%
X_validate_scaled_select8 = X_validate_scaled[['quarter', 'down', 'yardsToGo', 'team_by_comp_yds', 'numberOfPassRushers', 'QB_under_pressure', 'absoluteYardlineNumber', 'epa']]

# %%
print(ml.score(X_validate_scaled_select8, y_validate))

# %%
y_pred_val = ml.predict(X_validate_scaled_select8)

# %%
cm = pd.DataFrame(confusion_matrix(y_pred_val, y_validate))
cm

# %%
class_report = pd.DataFrame(classification_report(y_validate, y_pred_val, output_dict=True))
class_report

# %%
X_test_scaled_select8 = X_test_scaled[['quarter', 'down', 'yardsToGo', 'team_by_comp_yds', 'numberOfPassRushers', 'QB_under_pressure', 'absoluteYardlineNumber', 'epa']]

# %%
print(ml.score(X_test_scaled_select8, y_test))

# %%
feature_importances = pd.DataFrame(ml.feature_importances_,
                                   index = X_train_scaled.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

# %% [markdown]
# ## Logistic coeff

# %%
from sklearn.linear_model import LogisticRegression

# %%
logit = LogisticRegression()
logit.fit(X_train_scaled, y_train)
    
#creating a list comprehension for the column names
names = [column for column in X_train_scaled.columns]
#adding intercept to the end of the list
names.append('intercept')
#creating a dataframe from the regression coefficient values and intercept
coeff = pd.DataFrame(np.append(logit.coef_, logit.intercept_)).T
#renaming the column names with the list of names
coeff.columns = names

# %%
coeff.T

# %%
# ### Ridge Classifier

# clf = RidgeClassifierCV()
# clf.fit(X_train, y_train)
# print(clf.score(X_train, y_train))

# ### Random Forest

# tree = RandomForestClassifier()
# tree.fit(X_train, y_train)
# print(tree.score(X_train, y_train))

### Gradient Boost

# %%
### Ridge Classifier

# print(clf.score(X_validate, y_validate))

# ### Random Forest

# print(tree.score(X_validate, y_validate))

# %% [markdown]
# # RFE selection

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
import matplotlib as plt

# %%
estimators = [1,5,10,20,40]

# %%
select = RFE(RandomForestClassifier(n_estimators=5, random_state=42),
                 n_features_to_select=5)

# %%
select.fit(X_train, y_train)

# %%
mask = select.get_support() 
plt.pyplot.matshow(mask.reshape(1, -1), cmap='gray_r')

# %%
X_train

# %% [markdown]
# # Train and Validate Functions

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import mglearn

# %%
logreg = LogisticRegression()
scores = cross_val_score(logreg, X_train, y_train, cv = 5) 
print("Cross-validation scores: {}".format(scores))
print("Average cross-validation score: {:.2f}".format(scores.mean()))

# %% [markdown]
# ## Overfitting Parameters

# %%
from sklearn.svm import SVC

# %%
best_score = 0

for gamma in [0.001, 0.01, 0.1, 1, 10, 100]: 
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
            # for each combination of parameters, train an SVC
        svm = SVC(gamma=gamma, C=C)
        svm.fit(X_train, y_train)
        # evaluate the SVC on the validate set
        score = svm.score(X_validate, y_validate)
        # if we got a better score, store the score and parameters 
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}
print("Best score: {:.2f}".format(best_score)) 
print("Best parameters: {}".format(best_parameters))

# %%
test_score = svm.score(X_test, y_test)
test_score

# %% [markdown]
# ## Grid Search with Cross Validation

# %%
for gamma in [0.001, 0.01, 0.1, 1, 10, 100]: 
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
# for each combination of parameters, # train an SVC
        svm = SVC(gamma=gamma, C=C)
        # perform cross-validation
        scores = cross_val_score(svm, X_train, y_train, cv=5) # compute mean cross-validation accuracy
        score = np.mean(scores)
        # if we got a better score, store the score and parameters 
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}
# rebuild a model on the combined training and validation set 
svm = SVC(**best_parameters)
svm.fit(X_train, y_train)

# %%
mglearn.plots.plot_cross_val_selection()

# %%
# We are not using the validate stage to choose the test parameters

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.svm import SVC
import mglearn

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
                  'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
grid_search = GridSearchCV(SVC(), param_grid, cv=5)

# %%
grid_search.fit(X_train, y_train)

# %%
# The best_score_ attribute stores the mean cross-validation accuracy, 
# with cross-validation performed on the training set.
# be careful not to confuse best_score_ with the generaliza‐ tion 
# performance of the model as computed by the score method on the test set.

# %%
print("Validate set score: {:.2f}".format(grid_search.score(X_validate, y_validate)))
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
print("Best estimator:\n{}".format(grid_search.best_estimator_))

# %%
results = pd.DataFrame(grid_search.cv_results_) # show the first 5 rows 
results.head()

# %%
 scores = np.array(results.mean_test_score).reshape(6, 6)

# %%
# plot the mean cross-validation scores
mglearn.tools.heatmap(scores, xlabel='gamma', xticklabels=param_grid['gamma'],
                          ylabel='C', yticklabels=param_grid['C'], cmap="viridis")

# %%
fig, axes = plt.pyplot.subplots(1, 3, figsize=(13, 5))
param_grid_linear = {'C': np.linspace(1, 2, 6),
                     'gamma':  np.linspace(1, 2, 6)}
param_grid_one_log = {'C': np.linspace(1, 2, 6),
                      'gamma':  np.logspace(-3, 2, 6)}
param_grid_range = {'C': np.logspace(-3, 2, 6),
                    'gamma':  np.logspace(-7, -2, 6)}
for param_grid, ax in zip([param_grid_linear, param_grid_one_log, param_grid_range], axes):
    grid_search = GridSearchCV(SVC(), param_grid, cv=5)
    grid_search.fit(X_train, y_train)
    scores = grid_search.cv_results_['mean_test_score'].reshape(6, 6)
    # plot the mean cross-validation scores
    scores_image = mglearn.tools.heatmap(
        scores, xlabel='gamma', ylabel='C', xticklabels=param_grid['gamma'],
        yticklabels=param_grid['C'], cmap="viridis", ax=ax)
plt.colorbar(scores_image, ax=axes.tolist())

# %% [markdown]
# ## Nested Cross Validation

# %%
scores = cross_val_score(GridSearchCV(SVC(), param_grid, cv=5),
                             X_train, y_train, cv=5)
print("Cross-validation scores: ", scores) 
print("Mean cross-validation score: ", scores.mean())

# %%
def nested_cv(X, y, inner_cv, outer_cv, Classifier, parameter_grid): 
    outer_scores = []
    # for each split of the data in the outer cross-validation
    # (split method returns indices)
    for training_samples, test_samples in outer_cv.split(X, y): 
        # find best parameter using inner cross-validation 
        best_parms = {}
        best_score = -np.inf
        # iterate over parameters
        for parameters in parameter_grid:
            # accumulate score over inner splits 
            cv_scores = []
            # iterate over inner cross-validation
            for inner_train, inner_test in inner_cv.split(
                    X[training_samples], y[training_samples]):
                # build classifier given parameters and training data 
                clf = Classifier(**parameters) 
                clf.fit(X[inner_train], y[inner_train])
                # evaluate on inner test set
                score = clf.score(X[inner_test], y[inner_test]) 
                cv_scores.append(score)
            # compute mean score over inner folds
            mean_score = np.mean(cv_scores) 
            if mean_score > best_score:
                # if better than so far, remember parameters
                best_score = mean_score
                best_params = parameters
        # build classifier on best parameters using outer training set 
        clf = Classifier(**best_params)
        clf.fit(X[training_samples], y[training_samples])
        # evaluate
        outer_scores.append(clf.score(X[test_samples], y[test_samples]))
    return np.array(outer_scores)

# %%
from sklearn.model_selection import ParameterGrid, StratifiedKFold 
scores = nested_cv(X_train, y_train, StratifiedKFold(5),
            StratifiedKFold(5), SVC, ParameterGrid(param_grid)) 
print("Cross-validation scores: {}".format(scores))

# %% [markdown]
# # End
